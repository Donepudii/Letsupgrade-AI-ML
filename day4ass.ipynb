# %% [markdown]
# # question 1
# Research on whether addition, subtraction, multiplication, division, floor division, and modulo operations
# be performed on complex numbers. Based on your study, implement a Python program to demonstrate
# these operations.

# %%
a=4+9j
b=3+7j
print('addition is',a+b)
print('subtraction is',a-b)
print('multiplication is',a*b)
print('division is',a/b)
print('cant take floor on complex numbers')
print('modulo division is',abs(a))
# Out:
# addition is (7+16j)
# subtraction is (1+2j)
# multiplication is (-51+55j)
# division is (1.293103448275862-0.017241379310344876j)
# cant take floor on complex numbers
# modulo division is 9.848857801796104

# %% [markdown]
# # question 2
# # Range()
#  range() function is used to generate a sequence of numbers,by default starting from zero and increments,it stops before the specified number
#  if we consider range(x,y,z) here 'x' is first index and 'y' is end index and 'z' is step size.

# %%
for num in range(1,10,2):
  print(num,end=' ')
# Out:
# 1 3 5 7 9

# %% [markdown]
# # question 3
# Consider two numbers. Perform their subtraction and if the result of subtraction is greater than 25, print
# their multiplication result else print their division result.

# %%
a=int(input())
b=int(input())
result=a-b
if result>25:
  print(a*b)
else:
  print(a/b)

# %% [markdown]
# # question 4
# Consider a list of 10 elements of integer values. If the number in the list is divisible by 2, print the result as
# "square of that number minus 2".

# %%
l=list(range(1,11))
for i in l:
    if (i%2==0):
      print("square of that number muinus 2")
      break
# Out:
# square of that number muinus 2

# %% [markdown]
# # question 5
# Consider a list of 10 elements. Print all the elements in the list which are greater than 7 when that number
# is divided 2.

# %%
l=list(range(1,11))
for i in l:
  if (i>7) & (i%2==0):
    print(i)
# Out:
# 8
# 10
